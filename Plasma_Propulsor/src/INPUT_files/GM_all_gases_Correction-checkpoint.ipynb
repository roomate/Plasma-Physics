# %% [markdown]
# ### 16/11/2022
#
# ### The code works with 3 noble gases (Ar, Kr, Xe)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import sys
sys.path.append('../')
from LPP0D import *
from scipy.constants import k, e, m_e, epsilon_0, c,m_p
from scipy.special import jv
from tqdm import tqdm

# plt.style.use('./rcparams.mplstyle')

# %%
## Propellant choice : xenon, krypton or argon
gas = 'argon'

## Generated_file created
gen_diff_all_gases('input_{}.txt'.format(gas))
# Out:
# generated_diff_all_gases.py est ok!

# %%
## Objects creation : thruster, params, chem 
my_objects = generate_all_objects('input_{}.txt'.format(gas))

thruster = my_objects[0]
params = my_objects[1]
chem = my_objects[2]

init = chem.init_vector

# %% [markdown]
# # Objects inspection

# %%
verbose = True

if verbose:
    print(thruster)
    print(params)

    for a in chem.R.keys():
        for b in chem.R[a].keys():
            for d in chem.R[a][b].keys():
                print(d[:5])
                print(chem.R[a][b][d])
#                  pass
# Out:
# The thruster's parameters are:
#     R = 0.06 m
#     L = 0.1 m
#     R_coil = 2 Ohm
#     w = 85199992.76535518 Hz
#     N = 6
#     Vgrids = 1000 V
#     grid_dist = 0.001 m
#     r_coil = 0.065 m
#     l_coil = 0.1 m
#     beta_neutrals = 0.3
#     beta_ions = 0.7
#
#
# The parameters are:
#     Q0 = 1.12e+19 persecond
#     Q0 = 2.50e+01 sccm
#     Pabs = 1.50e+05 W/m3
#     I_coil = 5.00e+00 A
#     gamma = 0.02
#     T_wall = 300.0 K
#     sigma = 1.0e-18 m2
# IONIZ
# Reaction description:
#     [['Ar', 'e^-'], ['Ar^+', 'e^-', 'e^-'], 'IONIZATION']
#     \\wsl.localhost\Ubuntu\home\hugon\Projects\Plasma_Physics\Plasma_Propulsor\src\LPP0D/../lxcat/Ar_e_IONIZATION_rates_and_energy.csv
#     UQ coef: 1    K(3ev): 1.8662876763077705e-16
# ELAST
# Reaction description:
#     [['Ar', 'e^-'], ['Ar', 'e^-'], 'ELASTIC']
#     \\wsl.localhost\Ubuntu\home\hugon\Projects\Plasma_Physics\Plasma_Propulsor\src\LPP0D/../lxcat/Ar_e_ELASTIC_rates_and_energy.csv
#     UQ coef: 1    K(3ev): 9.427322403834042e-14
# EXCIT
# Reaction description:
#     [['Ar', 'e^-'], ['Ar', 'e^-'], 'EXCITATION1']
#     \\wsl.localhost\Ubuntu\home\hugon\Projects\Plasma_Physics\Plasma_Propulsor\src\LPP0D/../lxcat/Ar_e_EXCITATION1_rates_and_energy.csv
#     UQ coef: 1    K(3ev): 1.49279433473708e-16
# EXCIT
# Reaction description:
#     [['Ar', 'e^-'], ['Ar', 'e^-'], 'EXCITATION2']
#     \\wsl.localhost\Ubuntu\home\hugon\Projects\Plasma_Physics\Plasma_Propulsor\src\LPP0D/../lxcat/Ar_e_EXCITATION2_rates_and_energy.csv
#     UQ coef: 1    K(3ev): 1.656523201350166e-16
# EXCIT
# Reaction description:
#     [['Ar', 'e^-'], ['Ar', 'e^-'], 'EXCITATION3']
#     \\wsl.localhost\Ubuntu\home\hugon\Projects\Plasma_Physics\Plasma_Propulsor\src\LPP0D/../lxcat/Ar_e_EXCITATION3_rates_and_energy.csv
#     UQ coef: 1    K(3ev): 5.5013309981662227e-17

# %%
# print the rates used 

species = list_of_species('input_{}.txt'.format(gas))

fig, ax = plt.subplots(figsize=(7,5))
main_element = [a for a in chem.R.keys()][0]

ax.set_yscale('log')
# plt.tight_layout()
ax.set_ylim([1e-17, 1e-12])
ax.set_xlim([0,10])


ax.set_yticks([1e-17,1e-16,1e-15,1e-14,1e-13,1e-12])
ax.set_xlabel('$T_e$ (eV)')
ax.set_ylabel('K (m$^3$.s$^{-1}$)') 

if main_element == 'Ar':
    LABELS=['IONIZATION','ELASTIC','EXCITATION 1','EXCITATION 2','EXCITATION 3']
else:
    LABELS=['IONIZATION','ELASTIC','EXCITATION 1','EXCITATION 2','EXCITATION 3','EXCITATION 4']

Te_range = np.logspace(-2, 1,100)
compteur=0
for a in chem.R.keys():
    for b in chem.R[a].keys():
        for d in chem.R[a][b].keys():
            if 'e^-' in chem.R[a][b][d].reactants:
                ax.plot(Te_range, chem.R[a][b][d].K(Te_range), label= '%s'%LABELS[compteur])
                compteur+=1

ax.legend(fontsize=12,ncol=1,loc='lower right')
ax.set_title(main_element+' Reaction rates')

#ax.grid()
# Out:
# Text(0.5, 1.0, 'Ar Reaction rates')

# %% [markdown]
# # Useful functions

# %%
from scipy.constants import m_e, m_u, k, c, e, epsilon_0

m_Ar=39.95*m_u
m_Xe=131.293*m_u
m_Kr=83.798*m_u

def Jcl(mass,Voltage,distance_grids):
    """Child-Langmuir current (A/m2)
    INPUT : atomic mass, Acceleration voltage, distance between grids
    """
    return 4/9*epsilon_0*np.sqrt(e*2/mass)*Voltage**1.5/distance_grids**2


def R_coil(I):
    """ Coil resistance (Ohm)
    INPUT : I_coil 
    """
    return 2


def J_i(L, R, ng, ne, nIm, Te, Tg, n_ion, part):
    """Ion current (A/m2)
    INPUT : L, R, ng, ne, nIm, Te, Tg, n_ion, particle
    """
    hL = hl(L,ng,ne,nIm,Te,Tg,1e-18)                    # h factor
    
    return e * n_ion * hL * uB_GRONDEIN(Te,part)

def thrust_neutrals(ng,Tg,part):
    """Neutrals thrust (mN)
    INPUT : ng, Tg, particle
    """
    v_mean_gas = v_th(Tg, part)                   # Thermal speed  
    GammaG = 0.25 * ng * v_mean_gas               # neutral flux 
    Ag = thruster.open_area_neutrals()            # Open area for neutrals
    return GammaG * mass(part) * v_mean_gas * Ag 


def thrust_ions(L, R, ng, ne, nIm, Te, Tg, n_part, part):
    """Thrust from the ions (mN)
    INPUT : L, R, ng, ne, nIm, Te, Tg, n_part, part
    """
    M = mass(part)
    v_beam = np.sqrt(2 * e * thruster.Vgrids / M)                         # Beam speed
    Gammai = n_part * hl(L,ng,ne,nIm,Te,Tg,1e-18) * uB_GRONDEIN(Te,part)  # Ion flux
    Ai = thruster.open_area_ions()                                        # Open area for ions
    return Gammai * M * v_beam * Ai 

def IonThrustpower(L, R, ng, ne, nIm, Te, Tg, n_part, part):
    """Power used to accelerate ions: ion current times acceleration voltage.
    INPUT : L, R, ng, ne, nIm, Te, Tg, n_part, part
    """
    return J_i(L, R, ng, ne, nIm, Te, Tg, n_part, part) * thruster.open_area_ions() * thruster.Vgrids


def NeutralThrustpower(ng,Tg,part):
    """Power used to accelerate neutrals
    INPUT : ng, Tg, part
    """
    v_mean_gas = v_th(Tg, part)                                  # Thermal speed of the particle 'part'
    GammaG = 0.25 * ng * v_mean_gas                              # neutral flux 
    Ag = thruster.open_area_neutrals()                           # Open area for neutrals
    return 0.5 * mass(part) * GammaG * v_mean_gas**2 * Ag

# %% [markdown]
# # Run with temporal resolution

# %%
## Here the solver is called to run the simulation
results = solve_all_gases(thruster, params, chem, init, temporal=True)

# %%
main_element = [a for a in chem.R.keys()][0]
print('The propellant used is :',main_element)
species = list_of_species('input_{}.txt'.format(gas))
print('The species considered are :',species)

n_e = results.y[0]             # Electron density versus time         (m-3)
n_g = results.y[1]             # Gas density versus time              (m-3)
n_i = results.y[2]             # Ion density versus time              (m-3)
T_e = results.y[3]             # Electron temperature versus time     (eV) 
T_g = results.y[4]             # Gas temperature versus time          (eV)
res = results.y[:,-1]          # List of the last simulated physical quantities (n_e[-1], n_g[-1], n_i[-1], T_e[-1], T_g[-1])

R_induction = R_ind_noble_gas(n_e[-1],n_g[-1],
                              T_e[-1],T_g[-1],thruster.r_coil,thruster.l_coil,
                              thruster.w,thruster.N,chem.R,main_element)       # Inductive resistance (Ohm)

P_abs = 0.5*params.I_coil**2*R_induction                                       # Absorped Power (W)

RCoil = R_coil(params.I_coil)                                                  # Coil Resistance (Ohm)

P_RF = P_abs + 0.5 * params.I_coil**2*R_coil(params.I_coil)                    # RF Power (W)

P_coil = 0.5 * params.I_coil**2*R_coil(params.I_coil)                          # Power dissipated in the coil (W)

print('R_coil :',RCoil,'Ohm')
print('R_ind : %.2f Ohm'%R_induction)
print('P_coil : %.2f W' %P_coil)
print('P_abs : %.2f W'%P_abs)
print('P_RF : %.2f W'%P_RF)
# Out:
# The propellant used is : Ar
# The species considered are : ['e^-', 'Ar', 'Ar^+']
# R_coil : 2 Ohm
# R_ind : 5.13 Ohm
# P_coil : 25.00 W
# P_abs : 64.18 W
# P_RF : 89.18 W

# %%
main_element = [a for a in chem.R.keys()][0]


fig, ax = plt.subplots(2,2,figsize=(15,10))
ax[0,0].plot(n_e, label=r'n$_e$',linewidth=3)
ax[0,0].plot(n_g, label='n$_g$',linewidth=3)
ax[0,0].plot(n_i, label=r'n$_i$',linestyle='dashed',linewidth=3)
ax[0,0].legend(loc='best',ncol=1,fontsize=20)
ax[0,0].set_xscale('Log')
ax[0,0].set_yscale('Log')
ax[0,0].set_xlabel('Simulation steps')
ax[0,0].set_ylabel(r'Density (m$^{-3}$)')
ax[0,0].set_ylim(1e16,1e21)


ax[0,1].plot(T_e,linewidth=3)
ax[0,1].set_xscale('Log')
ax[0,1].set_xlabel('Simulation steps')
ax[0,1].set_ylabel(r'T$_e$ (eV)')
ax[0,1].set_ylim(0,6)

ax[1,0].plot(n_e, label='(-)',linewidth=3)
ax[1,0].plot(n_i, label='(+)',linestyle='dashed',linewidth=3,color='r')
ax[1,0].legend(loc='best',ncol=2,fontsize=25)
ax[1,0].set_xscale('Log')
ax[1,0].set_xlabel('Simulation steps')
ax[1,0].set_ylabel(r'Density (m$^{-3}$)')
ax[1,0].set_ylim(0,3e18)


ax[1,1].plot(T_g*e/k,linewidth=3)
ax[1,1].set_xscale('Log')
ax[1,1].set_xlabel('Simulation steps')
ax[1,1].set_ylabel(r'T$_{\rm{gas}}$ (K)')
ax[1,1].set_ylim(300,800)

ax[0,0].set_xlim(1,1000)
ax[1,0].set_xlim(1,1000)
ax[0,1].set_xlim(1,1000)
ax[1,1].set_xlim(1,1000)

plt.tight_layout()
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # Run for different $I_{coil}$ (Influence of the RF Power)

# %%
gen_diff_all_gases('input_{}.txt'.format(gas))

my_objects = generate_all_objects('input_{}.txt'.format(gas))

thruster = my_objects[0]
params = my_objects[1]
chem = my_objects[2]
main_element = [a for a in chem.R.keys()][0]

init = chem.init_vector


########################################################################
### INPUT found in the input file that can be directly modified here ###
######################################################################## 
I_COIL = np.arange(8,50,1)          # List of input current (A)

mass_flow_range = [29]                # List of input mass flow rate (sccm)

thruster.N = 6                        # Number of coil turns
thruster.R = 0.06                     # Coil radius (m)
thruster.L = 0.1                      # Coil length (m)
thruster.beta_ions = 0.7              # Grids transparency for ions
thruster.beta_neutrals = 0.3          # Grids transparency for neutrals
thruster.Vgrids = 1000                # Grids acceleraton voltage (V)
thruster.grid_dist = 1.e-3           # Distance between grids (m)

##########################################################

results = [] 

for mfr in tqdm(mass_flow_range):      # Loop on the mass flow rate (optional here)
    
    params.Q0 = sccm_to_persecond(mfr) # Convert sccm unit to s-1 (neutral flow rate)
    
    for I in I_COIL:                   # Loop on the coil current 
        
        params.I_coil = I              
    
        res_tmp = solve_all_gases(thruster, params, chem, init, temporal=False)  # Numerical resolution
        init = chem.init_vector                                                  # Use the latest converged solution as next input
        results.append([mfr, I, *res_tmp.y[:,-1]])                               # Append the results in the list results
        
# Convert the results into a DataFrame (Table)        
df_results = pd.DataFrame(results, columns=['mfc', 'I_coil', 'n_e', 'n_g', 'n_i', 'Te', 'Tg'])  

# Visualize the table results
df_results.head()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# generated_diff_all_gases.py est ok!
# 100%|██████████| 1/1 [00:16<00:00, 16.53s/it]
#    mfc  I_coil           n_e           n_g           n_i        Te        Tg
# 0   29       8  2.260234e+15  3.828746e+19  2.260234e+15  4.641560  0.025904
# 1   29       9  8.696047e+16  3.436068e+19  8.696047e+16  4.808366  0.027847
# 2   29      10  1.598314e+17  3.103092e+19  1.598314e+17  4.988344  0.029560
# 3   29      11  2.227202e+17  2.816397e+19  2.227202e+17  5.157963  0.031086
# 4   29      12  2.762542e+17  2.566954e+19  2.762542e+17  5.342286  0.032475

# %% [markdown]
# ## The table of results is filled with various physical quantities

# %%
R_ind_Istar_included=np.vectorize(R_ind_Istar_included)
R_ind_noble_gas=np.vectorize(R_ind_noble_gas)
R_ind=np.vectorize(R_ind)

## Pressure
df_results['total_pressure'] = (df_results.n_g*e*df_results.Tg+ df_results.n_e*e*df_results.Te+df_results.n_i*k**0.1*e)
df_results['neutral_pressure'] = (df_results.n_g*e*df_results.Tg )

## Electrical circuit
df_results['R_ind'] = R_ind_noble_gas(df_results.n_e,df_results.n_g,df_results.Te,df_results.Tg,thruster.r_coil,thruster.l_coil,thruster.w,thruster.N,chem.R,main_element)
df_results['Pd']   =  0.5*df_results['I_coil']**2*df_results['R_ind']
df_results['P_RF'] = df_results['Pd'] + 0.5*df_results['I_coil']**2*4#R_coil(df_results['I_coil'])
## Current
df_results['J_i'] = J_i(thruster.L,thruster.R,df_results.n_g,df_results.n_e,0,df_results.Te,df_results.Tg,df_results.n_i,main_element)
#
### Thrust
df_results['Thrust_i'] = thrust_ions(thruster.L,thruster.R,df_results.n_g,df_results.n_e,0,df_results.Te,df_results.Tg,df_results.n_i,main_element)
df_results['Thrust_g'] = thrust_neutrals(df_results.n_g,df_results.Tg,main_element)
df_results['Total_Thrust'] = df_results['Thrust_i']+df_results['Thrust_g']
#
### Ion / Neutral Power
df_results['Ions_Power'] = IonThrustpower(thruster.L,thruster.R,df_results.n_g,df_results.n_e,0,df_results.Te,df_results.Tg,df_results.n_i,main_element)
df_results['Neutrals_Power'] = NeutralThrustpower(df_results.n_g,df_results.Tg,main_element)
df_results['Total_Power'] = df_results['P_RF'] + df_results['Neutrals_Power'] + df_results['Ions_Power']
#
### Efficiencies
df_results['gamma'] = (df_results['Ions_Power']+df_results['Neutrals_Power'])/(df_results['Ions_Power']+df_results['Neutrals_Power']+df_results['P_RF'])
df_results['zeta'] = df_results['R_ind'] / (df_results['R_ind']+R_coil(df_results['I_coil']))
df_results['eta_mass'] = (df_results['Ions_Power']/(e * thruster.Vgrids))/(df_results['mfc']*4.47796e17)
df_results['eta_thruster'] = df_results['eta_mass']*df_results['gamma']

for a in chem.R.keys():
        for b in chem.R[a].keys():
            for d in chem.R[a][b].keys():
                df_results[d]=chem.R[a][b][d].K(df_results['Te'])
                df_results['E_'+c]=chem.R[a][b][d].energy_loss(df_results['Te'])
                
df_results['hL'] = hl(thruster.L,df_results.n_g,df_results.n_e,0,df_results.Te,df_results.Tg,params.sigma)
df_results['hR'] = hr(thruster.R,df_results.n_g,df_results.n_e,0,df_results.Te,df_results.Tg,params.sigma)
df_results['A_eff_loss'] = df_results['hL'] * 2 * np.pi * thruster.R**2 + 2 * np.pi * thruster.R * thruster.L * df_results['hR']
df_results['A_eff_wall'] = np.pi * thruster.R**2 * (2-thruster.beta_ions)*df_results['hL']+ 2 * np.pi * thruster.R * thruster.L * df_results['hR']
df_results['A_eff_open'] = np.pi * thruster.R**2 * thruster.beta_ions*df_results['hL']
df_results['A_n'] = np.pi * thruster.R**2 * (2-thruster.beta_neutrals) + 2 * np.pi * thruster.R * thruster.L

if main_element == 'Xe':
    df_results['E_cost'] = df_results['E_IONIZATION']+df_results['E_EXCITATION1']*df_results['EXCITATION1']/df_results['IONIZATION'] + df_results['E_EXCITATION2']*df_results['EXCITATION2']/df_results['IONIZATION'] + df_results['E_EXCITATION3']*df_results['EXCITATION3']/df_results['IONIZATION'] + df_results['E_EXCITATION4']*df_results['EXCITATION4']/df_results['IONIZATION']+3*m_e/m_Xe*df_results['ELASTIC']*e*df_results['Te']/df_results['IONIZATION']

# %%
## Save the result into a csv file

df_results.to_csv('./Test.csv',index=False)


## To access and read the saved csv file:

df = pd.read_csv('./Test.csv')
df.head()
# Out:
#    mfc  I_coil           n_e           n_g           n_i        Te        Tg  \
# 0   29       8  2.260234e+15  3.828746e+19  2.260234e+15  4.641560  0.025904
# 1   29       9  8.696047e+16  3.436068e+19  8.696047e+16  4.808366  0.027847
# 2   29      10  1.598314e+17  3.103092e+19  1.598314e+17  4.988344  0.029560
# 3   29      11  2.227202e+17  2.816397e+19  2.227202e+17  5.157963  0.031086
# 4   29      12  2.762542e+17  2.566954e+19  2.762542e+17  5.342286  0.032475
#
#    total_pressure  neutral_pressure     R_ind  ...   EXCITATION2  \
# 0        0.160585          0.158903  0.049837  ...  9.196600e-16
# 1        0.220369          0.153304  1.589618  ...  1.029643e-15
# 2        0.274835          0.146962  2.485324  ...  1.148880e-15
# 3        0.324509          0.140269  2.990950  ...  1.269209e-15
# 4        0.370243          0.133560  3.262592  ...  1.400213e-15
#
#    E_EXCITATION2   EXCITATION3  E_EXCITATION3        hL        hR  A_eff_loss  \
# 0           13.0  3.572906e-16           14.0  0.385470  0.317624    0.020693
# 1           13.0  4.056272e-16           14.0  0.393885  0.323967    0.021123
# 2           13.0  4.581488e-16           14.0  0.401407  0.329625    0.021506
# 3           13.0  5.127943e-16           14.0  0.408186  0.334715    0.021851
# 4           13.0  5.723530e-16           14.0  0.414337  0.339325    0.022164
#
#    A_eff_wall  A_eff_open       A_n
# 0    0.017642    0.003052  0.056926
# 1    0.018004    0.003118  0.056926
# 2    0.018328    0.003178  0.056926
# 3    0.018620    0.003232  0.056926
# 4    0.018884    0.003280  0.056926
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Densities vs Power

# %%
fig, ax = plt.subplots(1,2,figsize=(15,6))

ax[0].plot(df_results.P_RF, df_results.n_e, linewidth=2, label='$n_e$')
ax[0].plot(df_results.P_RF, df_results.n_g, linewidth=2, label='$n_g$')


ax[0].set_yscale('Log')
ax[0].set_xlabel(r'RF power (W)')
ax[0].set_ylabel(r'Densities (m$^{-3}$)')
ax[0].set_xlim([0, 1.5e3])
ax[0].set_ylim([1e16, 1e21])
ax[0].legend(loc='lower center',ncol=2,fontsize=25)
plt.tight_layout()



ax[1].plot(df_results.P_RF, df_results.Te, linewidth=2)


ax[1].set_xlabel(r'RF power (W)')
ax[1].set_ylabel(r'$T_e$  (eV)')
ax[1].set_xlim([0, 1.5e3])
ax[1].set_ylim([0,8])
plt.tight_layout()

fig, ax = plt.subplots(1,2,figsize=(15,6))

ax[0].plot(df_results.P_RF, df_results.neutral_pressure*7.5, linewidth=2)

ax[0].set_xlabel(r'RF power (W)')
ax[0].set_ylabel(r'Neutral Pressure  (mTorr)')
ax[0].set_xlim([0, 1.3e3])
ax[0].set_ylim([0,4])
plt.tight_layout()


ax[1].plot(df_results.P_RF, df_results.Tg* e/k, linewidth=2)

ax[1].set_xlabel(r'RF power (W)')
ax[1].set_ylabel(r'$T_g$  (K)')
ax[1].set_xlim([0, 1.3e3])
ax[1].set_ylim([300,1000])

plt.tight_layout()

# %%
fig, ax = plt.subplots(2,2,figsize=(15,12))

ax[0,0].plot(df_results.I_coil, df_results.n_e, linewidth=2, label='$n_e$')
ax[0,0].plot(df_results.I_coil, df_results.n_g, linewidth=2, label='$n_g$')
ng0=4*sccm_to_persecond(29)/np.sqrt(8*k*400/np.pi/m_Ar)/(np.pi*thruster.beta_neutrals*thruster.R**2)
ax[0,0].hlines(ng0,0,25,color='r',linestyle='dashed',label='$n_{g0}=%.1e$ m$^{-3}$'%ng0)
print(r'$n_{g0}=$',ng0)
ax[0,0].set_yscale('Log')
ax[0,0].set_xlabel(r'Coil current (A)')
nu_m=ng0*2e-13

def ne0(I):
    Numerator=np.pi*0.06*5**2*nu_m*(m_e/epsilon_0)**0.5
    Denominator=4*3000*(0.5*np.pi*0.06**2+0.5*np.pi*0.06*0.1)*e**2*0.1*c*50
    return (Numerator/Denominator)**(2/3)*I**(4/3)
II=np.linspace(0,25,50)

ax[0,0].plot(II,ne0(II),color='k',linestyle='dashed',label='$n_{e0}$')
ax[0,0].set_ylabel(r'Densities (m$^{-3}$)')
ax[0,0].set_xlim([0, 25])
ax[0,0].set_ylim([1e16, 1e21])
ax[0,0].legend(loc='lower center',ncol=2,fontsize=25)
plt.tight_layout()



ax[0,1].plot(df_results.I_coil, df_results.Te, linewidth=2)
ax[0,1].set_xlabel(r'Coil current (A)')
ax[0,1].set_ylabel(r'$T_e$  (eV)')
ax[0,1].set_xlim([0, 25])
ax[0,1].set_ylim([0,6])
Te0=-15.6/np.log(3000*(0.5 * 2 * np.pi * 0.06**2 + 2 * np.pi * 0.06 * 0.1 * 0.5)/ng0/1e-13/(np.pi*0.06**2*0.1))
print(Te0)
ax[0,1].hlines(Te0,0,25,color='r',linestyle='dashed',label='$T_{e0}=%.2f$ eV'%Te0)
ax[0,1].legend(fontsize=25)
ax[1,0].plot(df_results.I_coil, df_results.neutral_pressure*7.5, linewidth=2)
print('p0=',ng0*k*400*7.5)
ax[1,0].set_xlabel(r'Coil current (A)')
ax[1,0].hlines(ng0*k*400*7.5,0,25,color='r',linestyle='dashed',label='$p_0=%.2f$ mTorr'%(ng0*k*400*7.5))
ax[1,0].set_ylabel(r'Neutral Pressure  (mTorr)')
ax[1,0].set_xlim([0, 25])
ax[1,0].set_ylim([0,4])
ax[1,0].legend(fontsize=25)
plt.tight_layout()


ax[1,1].plot(df_results.I_coil, df_results.Tg* e/k, linewidth=2)

ax[1,1].set_xlabel(r'Coil current (A)')
ax[1,1].set_ylabel(r'$T_g$  (K)')
ax[1,1].hlines(400,0,25,color='r',linestyle='dashed')
ax[1,1].set_xlim([0, 25])
ax[1,1].set_ylim([300,700])

plt.tight_layout()
# Out:
# $n_{g0}=$ 3.325109955953381e+19
# 4.185412274921689
# p0= 1.3772429206731238

# %% [markdown]
# # PROPULSION Characteristics

# %% [markdown]
# ## Ion Current // Child Langmuir current

# %%
fig, ax = plt.subplots(figsize=(8,5))


ax.plot(df_results.P_RF, df_results.J_i, linewidth=2)

ax.set_xlabel(r'RF power (W)')
ax.set_ylabel(r'J (A/m$^2$)')
ax.set_xlim([0, 1.5e3])
ax.set_ylim([0,300])

plt.hlines(Jcl(m_Ar,thruster.Vgrids,thruster.grid_dist),0,1500,color='r',linestyle='dashed')

plt.tight_layout()
    
df_results['Min_Current']=np.abs(df_results.J_i-Jcl(m_Ar,thruster.Vgrids,thruster.grid_dist))

idx_min=list(df_results['Min_Current']).index(min(df_results['Min_Current']))
plt.vlines(df_results['P_RF'][idx_min],0,200,color='r',label='$P_{CL}=%.1f$ W'%df_results['P_RF'][idx_min],linestyle='--')
plt.legend(loc='upper left',fontsize=20)
print('Total Thrust = %.2f mN'%(df_results['Total_Thrust'][idx_min]*1000))
# Out:
# Total Thrust = 49.14 mN

# %% [markdown]
# # Thrust

# %%
fig, ax = plt.subplots(figsize=(8,5))

ax.plot(df_results.P_RF, df_results.Total_Thrust*1e3, linewidth=2)


ax.set_xlabel(r'RF power (W)')
ax.set_ylabel(r'Thrust (mN)')
ax.set_xlim([0, 1.5e3])
ax.set_ylim([0,80])
plt.tight_layout()

# %% [markdown]
# ## Thrust-to-Power ratio

# %%
plt.plot(df_results.P_RF,df_results.Total_Thrust/df_results.Total_Power*1e6,label='Exact Formula')
plt.plot(df_results.P_RF,df_results.Thrust_i/(df_results.Pd + df_results['Neutrals_Power'] + df_results['Ions_Power'])*1e6,label='Lecture Formula')
plt.tight_layout()

plt.xlabel(r'RF Power (W)')
plt.ylabel(r'T/P (mN/kW)')
plt.xlim(0,1500)
plt.ylim(0,50)
plt.legend(fontsize=25)
plt.tight_layout()

# %% [markdown]
# ## Efficiencies vs Power

# %%
fig, ax = plt.subplots(figsize=(8,5))


ax.plot(df_results.Total_Power, df_results.zeta, linewidth=2,label='Exact Formula')
df_results['nu_m']=df_results.n_g*df_results.ELASTIC
df_results['sigma_m']=df_results.n_e*e**2/m_e/df_results.nu_m
df_results['omega_pe']=np.sqrt(df_results.n_e*e**2/m_e/epsilon_0)
df_results['delta']=c/df_results['omega_pe']
df_results['Rind_simplified']=np.pi*thruster.N**2*thruster.R/(thruster.L*df_results.delta*df_results.sigma_m)

ax.plot(df_results.Total_Power,df_results['Rind_simplified']/(2+df_results['Rind_simplified']),label='Simplified Formula')
ax.legend(fontsize=20)

ax.set_xlabel(r'Total Power (W)')
ax.set_ylabel(r'Power Transfer efficiency')
ax.set_xlim([0,3000])
ax.set_ylim([0,1])
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(8,5))


ax.plot(df_results.Total_Power, df_results.gamma, linewidth=2,label='$\\gamma$')
ax.plot(df_results.Total_Power, df_results.eta_mass, linewidth=2,label='$\\eta_{mass}$')
ax.plot(df_results.Total_Power, df_results.eta_thruster, linewidth=2,label='$\\eta_{th}$')
ax.legend(fontsize=20)

ax.set_xlabel(r'Total Power (W)')
ax.set_ylabel(r'Efficiencies')
ax.set_xlim([0,3000])
ax.set_ylim([0,1])
plt.tight_layout()

# %% [markdown]
# ## Run for a fixed Jcl and for different mass flow rate

# %%
gen_diff_all_gases('input_{}.txt'.format(gas))

my_objects = generate_all_objects('input_{}.txt'.format(gas))

thruster = my_objects[0]
params = my_objects[1]
chem = my_objects[2]
main_element = [a for a in chem.R.keys()][0]

init = chem.init_vector


########################################################################
### INPUT found in the input file that can be directly modified here ###
######################################################################## 

#I_COIL = np.arange(10,80,2)          # List of input current (A)

mass_flow_range = np.arange(800,40,-20) # List of input mass flow rate (sccm)
              

thruster.N = 6                        # Number of coil turns
thruster.R = 0.06                     # thruster radius (m)
thruster.L = 0.1                      # Thruster length (m)
thruster.l_coil = thruster.L          # Coil length (m)
thruster.r_coil = 0.065               # Coil radius (m)
thruster.beta_ions = 0.7              # Grids transparency for ions
thruster.beta_neutrals = 0.3          # Grids transparency for neutrals
thruster.Vgrids = 1000                # Grids acceleraton voltage (V)
thruster.grid_dist = 1.e-3            # Distance between grids (m)

##########################################################
JCL_Xe=Jcl(m_Xe,thruster.Vgrids,thruster.grid_dist)
JCL_Ar=Jcl(m_Ar,thruster.Vgrids,thruster.grid_dist)
JCL_Kr=Jcl(m_Kr,thruster.Vgrids,thruster.grid_dist)

results = [] 

for mfr in tqdm(mass_flow_range):      # Loop on the mass flow rate (optional here)
    
    params.Q0 = sccm_to_persecond(mfr) # Convert sccm unit to s-1 (neutral flow rate)
    
    J_ions=0
    I=15
    delta_I=0.5
    while J_ions < JCL_Ar:
        
        params.I_coil = I
    
        res_tmp = solve_all_gases(thruster, params, chem, init, temporal=False)  # Numerical resolution
        init = chem.init_vector                                                  # Use the latest converged solution as next input
        J_ions=J_i(thruster.L,thruster.R,res_tmp.y[:,-1][1],res_tmp.y[:,-1][0],0,res_tmp.y[:,-1][3],res_tmp.y[:,-1][4],res_tmp.y[:,-1][2],main_element)
        print('ion Current=%.2f A/m2'%J_ions)
        I+=delta_I
    results.append([mfr, I, *res_tmp.y[:,-1]])
        
# Convert the results into a DataFrame (Table) 

df_results = pd.DataFrame(results, columns=['mfc', 'I_coil', 'n_e', 'n_g', 'n_i', 'Te', 'Tg'])  

# Visualize the table results
df_results.head()
# Out:
#   0%|          | 0/38 [00:00<?, ?it/s]
# generated_diff_all_gases.py est ok!
# ion Current=203.82 A/m2
# ion Current=212.96 A/m2
# ion Current=222.20 A/m2
# ion Current=231.53 A/m2
# ion Current=240.95 A/m2
# ion Current=250.46 A/m2
# ion Current=260.06 A/m2
# ion Current=269.74 A/m2
#   3%|▎         | 1/38 [00:03<02:06,  3.41s/it]
# ion Current=279.51 A/m2
# ion Current=203.66 A/m2
# ion Current=212.79 A/m2
# ion Current=222.02 A/m2
# ion Current=231.34 A/m2
# ion Current=240.75 A/m2
# ion Current=250.25 A/m2
# ion Current=259.84 A/m2
# ion Current=269.51 A/m2
#   5%|▌         | 2/38 [00:06<01:57,  3.27s/it]
# ion Current=279.27 A/m2
# ion Current=203.49 A/m2
# ion Current=212.62 A/m2
# ion Current=221.83 A/m2
# ion Current=231.14 A/m2
# ion Current=240.54 A/m2
# ion Current=250.03 A/m2
# ion Current=259.61 A/m2
# ion Current=269.28 A/m2
#   8%|▊         | 3/38 [00:09<01:52,  3.23s/it]
# ion Current=279.03 A/m2
# ion Current=203.32 A/m2
# ion Current=212.43 A/m2
# ion Current=221.63 A/m2
# ion Current=230.93 A/m2
# ion Current=240.33 A/m2
# ion Current=249.81 A/m2
# ion Current=259.38 A/m2
# ion Current=269.04 A/m2
#  11%|█         | 4/38 [00:12<01:45,  3.12s/it]
# ion Current=278.78 A/m2
# ion Current=203.13 A/m2
# ion Current=212.23 A/m2
# ion Current=221.43 A/m2
# ion Current=230.72 A/m2
# ion Current=240.10 A/m2
# ion Current=249.57 A/m2
# ion Current=259.13 A/m2
# ion Current=268.78 A/m2
#  13%|█▎        | 5/38 [00:15<01:40,  3.04s/it]
# ion Current=278.51 A/m2
# ion Current=202.93 A/m2
# ion Current=212.02 A/m2
# ion Current=221.21 A/m2
# ion Current=230.49 A/m2
# ion Current=239.87 A/m2
# ion Current=249.33 A/m2
# ion Current=258.88 A/m2
# ion Current=268.52 A/m2
#  16%|█▌        | 6/38 [00:18<01:35,  2.97s/it]
# ion Current=278.24 A/m2
# ion Current=202.72 A/m2
# ion Current=211.81 A/m2
# ion Current=220.98 A/m2
# ion Current=230.26 A/m2
# ion Current=239.62 A/m2
# ion Current=249.08 A/m2
# ion Current=258.62 A/m2
# ion Current=268.25 A/m2
#  18%|█▊        | 7/38 [00:20<01:30,  2.93s/it]
# ion Current=277.97 A/m2
# ion Current=202.50 A/m2
# ion Current=211.58 A/m2
# ion Current=220.75 A/m2
# ion Current=230.01 A/m2
# ion Current=239.37 A/m2
# ion Current=248.82 A/m2
# ion Current=258.35 A/m2
# ion Current=267.97 A/m2
#  21%|██        | 8/38 [00:23<01:27,  2.92s/it]
# ion Current=277.68 A/m2
# ion Current=202.28 A/m2
# ion Current=211.35 A/m2
# ion Current=220.51 A/m2
# ion Current=229.76 A/m2
# ion Current=239.11 A/m2
# ion Current=248.55 A/m2
# ion Current=258.08 A/m2
# ion Current=267.69 A/m2
#  24%|██▎       | 9/38 [00:26<01:23,  2.89s/it]
# ion Current=277.39 A/m2
# ion Current=202.05 A/m2
# ion Current=211.10 A/m2
# ion Current=220.26 A/m2
# ion Current=229.50 A/m2
# ion Current=238.84 A/m2
# ion Current=248.27 A/m2
# ion Current=257.80 A/m2
# ion Current=267.40 A/m2
#  26%|██▋       | 10/38 [00:29<01:20,  2.86s/it]
# ion Current=277.10 A/m2
# ion Current=201.81 A/m2
# ion Current=210.86 A/m2
# ion Current=220.00 A/m2
# ion Current=229.24 A/m2
# ion Current=238.57 A/m2
# ion Current=248.00 A/m2
# ion Current=257.51 A/m2
# ion Current=267.11 A/m2
#  29%|██▉       | 11/38 [00:32<01:17,  2.86s/it]
# ion Current=276.68 A/m2
# ion Current=201.56 A/m2
# ion Current=210.60 A/m2
# ion Current=219.74 A/m2
# ion Current=228.97 A/m2
# ion Current=238.30 A/m2
# ion Current=247.66 A/m2
# ion Current=257.04 A/m2
# ion Current=266.51 A/m2
#  32%|███▏      | 12/38 [00:35<01:14,  2.88s/it]
# ion Current=276.05 A/m2
# ion Current=201.31 A/m2
# ion Current=210.34 A/m2
# ion Current=219.47 A/m2
# ion Current=228.60 A/m2
# ion Current=237.79 A/m2
# ion Current=247.07 A/m2
# ion Current=256.43 A/m2
# ion Current=265.87 A/m2
#  34%|███▍      | 13/38 [00:37<01:11,  2.86s/it]
# ion Current=275.38 A/m2
# ion Current=201.03 A/m2
# ion Current=209.94 A/m2
# ion Current=218.94 A/m2
# ion Current=228.03 A/m2
# ion Current=237.20 A/m2
# ion Current=246.45 A/m2
# ion Current=255.78 A/m2
# ion Current=265.19 A/m2
#  37%|███▋      | 14/38 [00:40<01:08,  2.86s/it]
# ion Current=274.67 A/m2
# ion Current=200.50 A/m2
# ion Current=209.39 A/m2
# ion Current=218.36 A/m2
# ion Current=227.42 A/m2
# ion Current=236.57 A/m2
# ion Current=245.79 A/m2
# ion Current=255.09 A/m2
# ion Current=264.47 A/m2
#  39%|███▉      | 15/38 [00:43<01:06,  2.90s/it]
# ion Current=273.93 A/m2
# ion Current=199.94 A/m2
# ion Current=208.80 A/m2
# ion Current=217.75 A/m2
# ion Current=226.78 A/m2
# ion Current=235.89 A/m2
# ion Current=245.09 A/m2
# ion Current=254.36 A/m2
# ion Current=263.71 A/m2
# ion Current=273.14 A/m2
#  42%|████▏     | 16/38 [00:47<01:06,  3.01s/it]
# ion Current=282.64 A/m2
# ion Current=199.35 A/m2
# ion Current=208.18 A/m2
# ion Current=217.10 A/m2
# ion Current=226.10 A/m2
# ion Current=235.18 A/m2
# ion Current=244.35 A/m2
# ion Current=253.59 A/m2
# ion Current=262.92 A/m2
# ion Current=272.31 A/m2
#  45%|████▍     | 17/38 [00:50<01:04,  3.07s/it]
# ion Current=281.79 A/m2
# ion Current=198.71 A/m2
# ion Current=207.51 A/m2
# ion Current=216.40 A/m2
# ion Current=225.38 A/m2
# ion Current=234.43 A/m2
# ion Current=243.57 A/m2
# ion Current=252.78 A/m2
# ion Current=262.08 A/m2
# ion Current=271.45 A/m2
#  47%|████▋     | 18/38 [00:53<01:01,  3.07s/it]
# ion Current=280.89 A/m2
# ion Current=198.04 A/m2
# ion Current=206.81 A/m2
# ion Current=215.67 A/m2
# ion Current=224.61 A/m2
# ion Current=233.64 A/m2
# ion Current=242.75 A/m2
# ion Current=251.93 A/m2
# ion Current=261.20 A/m2
# ion Current=270.54 A/m2
#  50%|█████     | 19/38 [00:56<00:57,  3.05s/it]
# ion Current=279.95 A/m2
# ion Current=197.33 A/m2
# ion Current=206.07 A/m2
# ion Current=214.90 A/m2
# ion Current=223.81 A/m2
# ion Current=232.81 A/m2
# ion Current=241.88 A/m2
# ion Current=251.04 A/m2
# ion Current=260.27 A/m2
# ion Current=269.58 A/m2
#  53%|█████▎    | 20/38 [00:59<00:54,  3.04s/it]
# ion Current=278.97 A/m2
# ion Current=196.58 A/m2
# ion Current=205.29 A/m2
# ion Current=214.09 A/m2
# ion Current=222.97 A/m2
# ion Current=231.94 A/m2
# ion Current=240.98 A/m2
# ion Current=250.10 A/m2
# ion Current=259.19 A/m2
# ion Current=268.35 A/m2
#  55%|█████▌    | 21/38 [01:02<00:51,  3.03s/it]
# ion Current=277.57 A/m2
# ion Current=195.79 A/m2
# ion Current=204.47 A/m2
# ion Current=213.24 A/m2
# ion Current=222.00 A/m2
# ion Current=230.83 A/m2
# ion Current=239.72 A/m2
# ion Current=248.68 A/m2
# ion Current=257.72 A/m2
# ion Current=266.82 A/m2
#  58%|█████▊    | 22/38 [01:05<00:48,  3.02s/it]
# ion Current=275.98 A/m2
# ion Current=194.81 A/m2
# ion Current=203.35 A/m2
# ion Current=211.97 A/m2
# ion Current=220.66 A/m2
# ion Current=229.42 A/m2
# ion Current=238.25 A/m2
# ion Current=247.16 A/m2
# ion Current=256.13 A/m2
# ion Current=265.17 A/m2
#  61%|██████    | 23/38 [01:08<00:45,  3.01s/it]
# ion Current=274.27 A/m2
# ion Current=193.54 A/m2
# ion Current=202.02 A/m2
# ion Current=210.57 A/m2
# ion Current=219.20 A/m2
# ion Current=227.90 A/m2
# ion Current=236.67 A/m2
# ion Current=245.51 A/m2
# ion Current=254.42 A/m2
# ion Current=263.39 A/m2
# ion Current=272.43 A/m2
#  63%|██████▎   | 24/38 [01:11<00:42,  3.06s/it]
# ion Current=281.53 A/m2
# ion Current=192.16 A/m2
# ion Current=200.57 A/m2
# ion Current=209.06 A/m2
# ion Current=217.62 A/m2
# ion Current=226.26 A/m2
# ion Current=234.96 A/m2
# ion Current=243.74 A/m2
# ion Current=252.58 A/m2
# ion Current=261.48 A/m2
# ion Current=270.45 A/m2
#  66%|██████▌   | 25/38 [01:14<00:40,  3.12s/it]
# ion Current=279.48 A/m2
# ion Current=190.65 A/m2
# ion Current=199.00 A/m2
# ion Current=207.42 A/m2
# ion Current=215.92 A/m2
# ion Current=224.49 A/m2
# ion Current=233.12 A/m2
# ion Current=241.83 A/m2
# ion Current=250.60 A/m2
# ion Current=259.44 A/m2
# ion Current=268.33 A/m2
#  68%|██████▊   | 26/38 [01:18<00:38,  3.21s/it]
# ion Current=277.30 A/m2
# ion Current=189.03 A/m2
# ion Current=197.31 A/m2
# ion Current=205.66 A/m2
# ion Current=214.09 A/m2
# ion Current=222.58 A/m2
# ion Current=231.15 A/m2
# ion Current=239.75 A/m2
# ion Current=248.35 A/m2
# ion Current=257.00 A/m2
# ion Current=265.70 A/m2
#  71%|███████   | 27/38 [01:21<00:36,  3.29s/it]
# ion Current=274.46 A/m2
# ion Current=187.27 A/m2
# ion Current=195.41 A/m2
# ion Current=203.59 A/m2
# ion Current=211.84 A/m2
# ion Current=220.14 A/m2
# ion Current=228.51 A/m2
# ion Current=236.94 A/m2
# ion Current=245.42 A/m2
# ion Current=253.95 A/m2
# ion Current=262.54 A/m2
# ion Current=271.18 A/m2
#  74%|███████▎  | 28/38 [01:25<00:34,  3.48s/it]
# ion Current=279.87 A/m2
# ion Current=184.88 A/m2
# ion Current=192.88 A/m2
# ion Current=200.95 A/m2
# ion Current=209.08 A/m2
# ion Current=217.27 A/m2
# ion Current=225.52 A/m2
# ion Current=233.82 A/m2
# ion Current=242.18 A/m2
# ion Current=250.59 A/m2
# ion Current=259.06 A/m2
# ion Current=267.57 A/m2
#  76%|███████▋  | 29/38 [01:29<00:32,  3.56s/it]
# ion Current=276.14 A/m2
# ion Current=182.18 A/m2
# ion Current=190.07 A/m2
# ion Current=198.01 A/m2
# ion Current=206.01 A/m2
# ion Current=214.08 A/m2
# ion Current=222.20 A/m2
# ion Current=230.37 A/m2
# ion Current=238.60 A/m2
# ion Current=246.88 A/m2
# ion Current=255.22 A/m2
# ion Current=263.60 A/m2
# ion Current=272.03 A/m2
#  79%|███████▉  | 30/38 [01:33<00:30,  3.76s/it]
# ion Current=280.51 A/m2
# ion Current=179.18 A/m2
# ion Current=186.93 A/m2
# ion Current=194.74 A/m2
# ion Current=202.61 A/m2
# ion Current=210.54 A/m2
# ion Current=218.47 A/m2
# ion Current=226.41 A/m2
# ion Current=234.40 A/m2
# ion Current=242.42 A/m2
# ion Current=250.49 A/m2
# ion Current=258.60 A/m2
# ion Current=266.75 A/m2
#  82%|████████▏ | 31/38 [01:37<00:26,  3.85s/it]
# ion Current=274.94 A/m2
# ion Current=175.57 A/m2
# ion Current=183.07 A/m2
# ion Current=190.63 A/m2
# ion Current=198.24 A/m2
# ion Current=205.89 A/m2
# ion Current=213.59 A/m2
# ion Current=221.34 A/m2
# ion Current=229.12 A/m2
# ion Current=236.95 A/m2
# ion Current=244.81 A/m2
# ion Current=252.72 A/m2
# ion Current=260.65 A/m2
# ion Current=268.63 A/m2
#  84%|████████▍ | 32/38 [01:42<00:24,  4.05s/it]
# ion Current=276.63 A/m2
# ion Current=171.06 A/m2
# ion Current=178.36 A/m2
# ion Current=185.71 A/m2
# ion Current=193.10 A/m2
# ion Current=200.54 A/m2
# ion Current=208.03 A/m2
# ion Current=215.55 A/m2
# ion Current=223.12 A/m2
# ion Current=230.72 A/m2
# ion Current=238.36 A/m2
# ion Current=245.98 A/m2
# ion Current=253.59 A/m2
# ion Current=261.22 A/m2
# ion Current=268.88 A/m2
#  87%|████████▋ | 33/38 [01:46<00:20,  4.20s/it]
# ion Current=276.56 A/m2
# ion Current=165.81 A/m2
# ion Current=172.81 A/m2
# ion Current=179.84 A/m2
# ion Current=186.91 A/m2
# ion Current=194.01 A/m2
# ion Current=201.15 A/m2
# ion Current=208.31 A/m2
# ion Current=215.51 A/m2
# ion Current=222.73 A/m2
# ion Current=229.98 A/m2
# ion Current=237.25 A/m2
# ion Current=244.54 A/m2
# ion Current=251.85 A/m2
# ion Current=259.19 A/m2
# ion Current=266.54 A/m2
#  89%|████████▉ | 34/38 [01:51<00:17,  4.29s/it]
# ion Current=273.91 A/m2
# ion Current=158.94 A/m2
# ion Current=165.62 A/m2
# ion Current=172.33 A/m2
# ion Current=179.07 A/m2
# ion Current=185.85 A/m2
# ion Current=192.65 A/m2
# ion Current=199.48 A/m2
# ion Current=206.33 A/m2
# ion Current=213.14 A/m2
# ion Current=219.95 A/m2
# ion Current=226.78 A/m2
# ion Current=233.61 A/m2
# ion Current=240.46 A/m2
# ion Current=247.31 A/m2
# ion Current=254.17 A/m2
# ion Current=261.03 A/m2
# ion Current=267.90 A/m2
#  92%|█████████▏| 35/38 [01:56<00:13,  4.45s/it]
# ion Current=274.77 A/m2
# ion Current=150.35 A/m2
# ion Current=156.57 A/m2
# ion Current=162.81 A/m2
# ion Current=169.08 A/m2
# ion Current=175.35 A/m2
# ion Current=181.65 A/m2
# ion Current=187.96 A/m2
# ion Current=194.28 A/m2
# ion Current=200.62 A/m2
# ion Current=206.96 A/m2
# ion Current=213.31 A/m2
# ion Current=219.66 A/m2
# ion Current=225.96 A/m2
# ion Current=232.24 A/m2
# ion Current=238.51 A/m2
# ion Current=244.77 A/m2
# ion Current=251.03 A/m2
# ion Current=257.28 A/m2
# ion Current=263.52 A/m2
# ion Current=269.75 A/m2
#  95%|█████████▍| 36/38 [02:02<00:09,  4.91s/it]
# ion Current=275.96 A/m2
# ion Current=139.03 A/m2
# ion Current=144.67 A/m2
# ion Current=150.32 A/m2
# ion Current=155.98 A/m2
# ion Current=161.65 A/m2
# ion Current=167.31 A/m2
# ion Current=172.98 A/m2
# ion Current=178.65 A/m2
# ion Current=184.31 A/m2
# ion Current=189.97 A/m2
# ion Current=195.63 A/m2
# ion Current=201.26 A/m2
# ion Current=206.82 A/m2
# ion Current=212.37 A/m2
# ion Current=217.90 A/m2
# ion Current=223.42 A/m2
# ion Current=228.92 A/m2
# ion Current=234.39 A/m2
# ion Current=239.85 A/m2
# ion Current=245.28 A/m2
# ion Current=250.69 A/m2
# ion Current=256.07 A/m2
# ion Current=261.43 A/m2
# ion Current=266.76 A/m2
# ion Current=272.06 A/m2
#  97%|█████████▋| 37/38 [02:10<00:05,  5.89s/it]
# ion Current=277.34 A/m2
# ion Current=123.48 A/m2
# ion Current=128.37 A/m2
# ion Current=133.24 A/m2
# ion Current=138.11 A/m2
# ion Current=142.98 A/m2
# ion Current=147.81 A/m2
# ion Current=152.59 A/m2
# ion Current=157.35 A/m2
# ion Current=162.10 A/m2
# ion Current=166.82 A/m2
# ion Current=171.52 A/m2
# ion Current=176.19 A/m2
# ion Current=180.84 A/m2
# ion Current=185.46 A/m2
# ion Current=190.05 A/m2
# ion Current=194.62 A/m2
# ion Current=199.15 A/m2
# ion Current=203.66 A/m2
# ion Current=208.09 A/m2
# ion Current=212.47 A/m2
# ion Current=216.81 A/m2
# ion Current=221.11 A/m2
# ion Current=225.37 A/m2
# ion Current=229.59 A/m2
# ion Current=233.78 A/m2
# ion Current=237.92 A/m2
# ion Current=242.03 A/m2
# ion Current=246.09 A/m2
# ion Current=250.11 A/m2
# ion Current=254.09 A/m2
# ion Current=258.02 A/m2
# ion Current=261.86 A/m2
# ion Current=265.65 A/m2
# ion Current=269.40 A/m2
# ion Current=273.10 A/m2
# 100%|██████████| 38/38 [02:22<00:00,  3.76s/it]
# ion Current=276.77 A/m2
#    mfc  I_coil           n_e           n_g           n_i        Te        Tg
# 0  800    19.5  5.379728e+18  4.292117e+20  5.379728e+18  2.359295  0.145517
# 1  780    19.5  5.301765e+18  4.220143e+20  5.301765e+18  2.368401  0.142807
# 2  760    19.5  5.222564e+18  4.147252e+20  5.222564e+18  2.378073  0.140091
# 3  740    19.5  5.142127e+18  4.073390e+20  5.142127e+18  2.388364  0.137372
# 4  720    19.5  5.060357e+18  3.998525e+20  5.060357e+18  2.399336  0.134649

# %%
R_ind_Istar_included=np.vectorize(R_ind_Istar_included)
R_ind_noble_gas=np.vectorize(R_ind_noble_gas)
R_ind=np.vectorize(R_ind)

## Pressure
df_results['total_pressure'] = (df_results.n_g*e*df_results.Tg+ df_results.n_e*e*df_results.Te+df_results.n_i*k**0.1*e)
df_results['neutral_pressure'] = (df_results.n_g*e*df_results.Tg )

## Electrical circuit
df_results['R_ind'] = R_ind_noble_gas(df_results.n_e,df_results.n_g,df_results.Te,df_results.Tg,thruster.r_coil,thruster.l_coil,thruster.w,thruster.N,chem.R,main_element)
df_results['Pd']   =  0.5*df_results['I_coil']**2*df_results['R_ind']
df_results['P_RF'] = df_results['Pd'] + 0.5*df_results['I_coil']**2*4#R_coil(df_results['I_coil'])
## Current
df_results['J_i'] = J_i(thruster.L,thruster.R,df_results.n_g,df_results.n_e,0,df_results.Te,df_results.Tg,df_results.n_i,main_element)
#
### Thrust
df_results['Thrust_i'] = thrust_ions(thruster.L,thruster.R,df_results.n_g,df_results.n_e,0,df_results.Te,df_results.Tg,df_results.n_i,main_element)
df_results['Thrust_g'] = thrust_neutrals(df_results.n_g,df_results.Tg,main_element)
df_results['Total_Thrust'] = df_results['Thrust_i']+df_results['Thrust_g']
#
### Ion / Neutral Power
df_results['Ions_Power'] = IonThrustpower(thruster.L,thruster.R,df_results.n_g,df_results.n_e,0,df_results.Te,df_results.Tg,df_results.n_i,main_element)
df_results['Neutrals_Power'] = NeutralThrustpower(df_results.n_g,df_results.Tg,main_element)
df_results['Total_Power'] = df_results['P_RF'] + df_results['Neutrals_Power'] + df_results['Ions_Power']
#
### Efficiencies
df_results['gamma'] = (df_results['Ions_Power']+df_results['Neutrals_Power'])/(df_results['Ions_Power']+df_results['Neutrals_Power']+df_results['P_RF'])
df_results['zeta'] = df_results['R_ind'] / (df_results['R_ind']+R_coil(df_results['I_coil']))
df_results['eta_mass'] = (df_results['Ions_Power']/(e * thruster.Vgrids))/(df_results['mfc']*4.47796e17)
df_results['eta_thruster'] = df_results['eta_mass']*df_results['gamma']

for a in chem.R.keys():
        for b in chem.R[a].keys():
            for c in chem.R[a][b].keys():
                df_results[c]=chem.R[a][b][c].K(df_results['Te'])
                df_results['E_'+c]=chem.R[a][b][c].energy_loss(df_results['Te'])
                
df_results['hL'] = hl(thruster.L,df_results.n_g,df_results.n_e,0,df_results.Te,df_results.Tg,params.sigma)
df_results['hR'] = hr(thruster.R,df_results.n_g,df_results.n_e,0,df_results.Te,df_results.Tg,params.sigma)
df_results['A_eff_loss'] = df_results['hL'] * 2 * np.pi * thruster.R**2 + 2 * np.pi * thruster.R * thruster.L * df_results['hR']
df_results['A_eff_wall'] = np.pi * thruster.R**2 * (2-thruster.beta_ions)*df_results['hL']+ 2 * np.pi * thruster.R * thruster.L * df_results['hR']
df_results['A_eff_open'] = np.pi * thruster.R**2 * thruster.beta_ions*df_results['hL']
df_results['A_n'] = np.pi * thruster.R**2 * (2-thruster.beta_neutrals) + 2 * np.pi * thruster.R * thruster.L

if main_element == 'Xe':
    df_results['E_cost'] = df_results['E_IONIZATION']+df_results['E_EXCITATION1']*df_results['EXCITATION1']/df_results['IONIZATION'] + df_results['E_EXCITATION2']*df_results['EXCITATION2']/df_results['IONIZATION'] + df_results['E_EXCITATION3']*df_results['EXCITATION3']/df_results['IONIZATION'] + df_results['E_EXCITATION4']*df_results['EXCITATION4']/df_results['IONIZATION']+3*m_e/m_Xe*df_results['ELASTIC']*e*df_results['Te']/df_results['IONIZATION']

# %%
plt.scatter(df_results.mfc*0.18872*m_Kr/m_Xe,df_results.J_i)
plt.hlines(JCL_Kr*np.ones(50),0,40)
plt.ylim(0,300)
# Out:
# (0.0, 300.0)

# %%
plt.plot(df_results.mfc*0.18872*m_Ar/m_Xe,df_results.eta_mass)
plt.plot(df_results.mfc*0.18872*m_Ar/m_Xe,df_results.eta_thruster)
#plt.plot(df_results.mfc*0.18872,df_results.zeta)
plt.plot(df_results.mfc*0.18872*m_Ar/m_Xe,df_results.gamma)

plt.xlabel(r'$Q_0$ (mg/s)')
plt.ylabel(r'Efficiencies')
plt.xlim([0, 40])
plt.ylim([0,1])
plt.tight_layout()

# %%
plt.plot(df_results.mfc*0.18872,df_results.eta_mass*df_results.gamma)
plt.xlim(0,40)

plt.xlabel(r'$Q_0$ (mg/s)')
plt.ylabel(r'Thruster Efficiency')

plt.tight_layout()

# %%
#df_results.to_csv('./Mass_flow_study_Argon_L_10cm_low_flow.csv')

# %%
df_Xe_10cm=pd.read_csv('./Mass_flow_study_Xenon_L_10cm.csv')

df_Xe_3cm=pd.read_csv('./Mass_flow_study_Xenon_L_3cm.csv')

df_Ar_3cm_low_flow=pd.read_csv('./Mass_flow_study_Argon_L_3cm_low_flow.csv')
df_Ar_3cm_high_flow=pd.read_csv('./Mass_flow_study_Argon_L_3cm_high_flow.csv')
df_Ar_3cm=df_Ar_3cm_low_flow.append(df_Ar_3cm_high_flow)

df_Ar_10cm_low_flow=pd.read_csv('./Mass_flow_study_Argon_L_10cm_low_flow.csv')
df_Ar_10cm_high_flow=pd.read_csv('./Mass_flow_study_Argon_L_10cm_high_flow.csv')
df_Ar_10cm=df_Ar_10cm_low_flow.append(df_Ar_10cm_high_flow)

df_Kr_3cm_low_flow=pd.read_csv('./Mass_flow_study_Krypton_L_3cm_low_flow.csv')
df_Kr_3cm_high_flow=pd.read_csv('./Mass_flow_study_Krypton_L_3cm_high_flow.csv')
df_Kr_3cm=df_Kr_3cm_low_flow.append(df_Kr_3cm_high_flow)

df_Kr_10cm_low_flow=pd.read_csv('./Mass_flow_study_Krypton_L_10cm_low_flow.csv')
df_Kr_10cm_high_flow=pd.read_csv('./Mass_flow_study_Krypton_L_10cm_high_flow.csv')
df_Kr_10cm=df_Kr_10cm_low_flow.append(df_Kr_10cm_high_flow)

df_Xe_3cm=df_Xe_3cm.sort_values('mfc')
df_Xe_10cm=df_Xe_10cm.sort_values('mfc')
df_Ar_3cm=df_Ar_3cm.sort_values('mfc')
df_Ar_10cm=df_Ar_10cm.sort_values('mfc')
df_Kr_3cm=df_Kr_3cm.sort_values('mfc')
df_Kr_10cm=df_Kr_10cm.sort_values('mfc')

# %%
plt.plot(df_Xe_10cm.mfc*0.18872,df_Xe_10cm.eta_mass,label='Mass Efficiency')
plt.plot(df_Xe_10cm.mfc*0.18872,df_Xe_10cm.eta_thruster,label='Thruster Efficiency')
plt.plot(df_Xe_10cm.mfc*0.18872,df_Xe_10cm.gamma,label='PTE')

plt.xlabel(r'$Q_0$ (mg/s)')
plt.ylabel(r'Efficiencies')
plt.xlim([0, 40])
plt.ylim([0,1])
plt.legend(fontsize=20)
plt.tight_layout()

# %%
plt.plot(df_Xe_10cm.mfc*0.18872,df_Xe_10cm.eta_thruster,label='$L=10$ cm')
plt.plot(df_Xe_3cm.mfc*0.18872,df_Xe_3cm.eta_thruster,label='$L=3$ cm')

plt.xlabel(r'$Q_0$ (mg/s)')
plt.ylabel(r'Thruster Efficiency')
plt.xlim([0, 40])
plt.ylim([0,0.5])
plt.legend(fontsize=20)
plt.tight_layout()

# %%
print(df_Xe_10cm.R_ind,df_Kr_10cm.R_ind,df_Ar_10cm.R_ind)
# Out:
# 91    0.294196
# 90    0.708586
# 89    1.080321
# 88    1.378483
# 87    1.675383
#         ...
# 4     7.771119
# 3     7.793684
# 2     7.816238
# 1     7.838723
# 0     7.861146
# Name: R_ind, Length: 92, dtype: float64 9      0.176156
# 8      1.186414
# 7      2.058308
# 6      2.829017
# 5      3.523337
# 4      4.267481
# 3      4.825429
# 2      5.443760
# 1      6.132741
# 0      6.634732
# 18     6.681900
# 17    11.313719
# 16    14.778812
# 15    17.387772
# 14    19.489691
# 13    21.177200
# 12    22.572307
# 11    23.907086
# 10    24.835025
# 9     25.528240
# 8     26.562677
# 7     27.203712
# 6     27.812582
# 5     28.291415
# 4     28.697621
# 3     29.091937
# 2     29.926212
# 1     30.310811
# 0     30.684310
# Name: R_ind, dtype: float64 8      0.598225
# 7      1.315388
# 6      1.906470
# 5      2.440540
# 4      2.971669
# 3      3.364881
# 2      3.819370
# 1      4.345148
# 0      4.721845
# 37     6.703866
# 36     9.926362
# 35    12.358934
# 34    14.475833
# 33    16.217926
# 32    17.680752
# 31    18.845692
# 30    20.101725
# 29    21.142770
# 28    22.024558
# 27    22.664597
# 26    23.522005
# 25    24.087361
# 24    24.793013
# 23    25.230704
# 22    25.650433
# 21    26.358763
# 20    26.758093
# 19    27.125406
# 18    27.404413
# 17    27.676437
# 16    28.275791
# 15    28.543628
# 14    28.804852
# 13    29.059778
# 12    29.308694
# 11    29.551928
# 10    29.789714
# 9     29.993047
# 8     30.149693
# 7     30.304706
# 6     30.458080
# 5     30.999033
# 4     31.154778
# 3     31.308584
# 2     31.460468
# 1     31.610451
# 0     31.758589
# Name: R_ind, dtype: float64

# %%
plt.plot(df_Xe_3cm.mfc*0.18872,df_Xe_3cm.eta_thruster,label='Xenon')
plt.plot(df_Ar_3cm.mfc*0.18872*m_Ar/m_Xe,df_Ar_3cm.eta_thruster,label='Argon',color='m')
plt.plot(df_Kr_3cm.mfc*0.18872*m_Kr/m_Xe,df_Kr_3cm.eta_thruster,label='Krypton',color='brown')


plt.xlabel(r'$Q_0$ (mg/s)')
plt.ylabel(r'Thruster Efficiency')
plt.xlim([0, 40])
plt.ylim([0,0.5])
plt.legend(fontsize=25)
plt.title('$L=3$ cm')
plt.tight_layout()

plt.figure()

plt.plot(df_Xe_10cm.mfc*0.18872,df_Xe_10cm.eta_thruster,label='Xenon')
plt.plot(df_Ar_10cm.mfc*0.18872*m_Ar/m_Xe,df_Ar_10cm.eta_thruster,label='Argon',color='m')
plt.plot(df_Kr_10cm.mfc*0.18872*m_Kr/m_Xe,df_Kr_10cm.eta_thruster,label='Krypton',color='brown')


plt.xlabel(r'$Q_0$ (mg/s)')
plt.ylabel(r'Thruster Efficiency')
plt.xlim([0, 40])
plt.ylim([0,0.5])
plt.legend(fontsize=25)
plt.title('$L=10$ cm')
plt.tight_layout()

# %%
plt.plot(df_Xe_3cm.mfc*0.18872,df_Xe_3cm.Total_Thrust/df_Xe_3cm.Total_Power*1e6,label='Xenon')
plt.plot(df_Ar_3cm.mfc*0.18872*m_Ar/m_Xe,df_Ar_3cm.Total_Thrust/df_Ar_3cm.Total_Power*1e6,label='Argon',color='m')
plt.plot(df_Kr_3cm.mfc*0.18872*m_Kr/m_Xe,df_Kr_3cm.Total_Thrust/df_Kr_3cm.Total_Power*1e6,label='Krypton',color='brown')


plt.xlabel(r'$Q_0$ (mg/s)')
plt.ylabel(r'Thrust-to-power ratio (mN/kW)')
plt.xlim([0, 40])
#plt.ylim([0,0.5])
plt.legend(fontsize=25)
plt.tight_layout()

# %%
plt.scatter(df_Xe_3cm.mfc*0.18872,df_Xe_3cm.Total_Thrust*1000,label='Xenon')
plt.scatter(df_Ar_3cm.mfc*0.18872*m_Ar/m_Xe,df_Ar_3cm.Total_Thrust*1000,label='Argon',color='m')
plt.scatter(df_Kr_3cm.mfc*0.18872*m_Kr/m_Xe,df_Kr_3cm.Total_Thrust*1000,label='Krypton',color='brown')


plt.xlabel(r'$Q_0$ (mg/s)')
plt.ylabel(r'Thrust (mN)')
plt.xlim([0, 40])
plt.ylim([0,100])
plt.legend(fontsize=25)
plt.tight_layout()
